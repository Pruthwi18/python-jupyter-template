# %% [markdown]
# ### Exercise 5: Subplot Layout

# %%
# TASK: Create a 2x2 subplot layout.
# Plot a line chart in the first subplot, a bar chart in the second, a scatter plot in the third, and a pie chart in the fourth.
import matplotlib.pyplot as plt

# Data
x = [1, 2, 3, 4, 5]
y_line = [1, 4, 9, 16, 25]
y_bar = [5, 7, 3, 9]
x_scatter = [1, 2, 3, 4, 5]
y_scatter = [1, 4, 9, 16, 25]
labels_pie = ['Python', 'Java', 'C++', 'JavaScript']
sizes_pie = [40, 25, 20, 15]

# Create 2x2 subplot layout
fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# First subplot - Line Chart
axs[0, 0].plot(x, y_line, label='y = x^2', color='blue')
axs[0, 0].set_title('Line Chart')
axs[0, 0].legend()

# Second subplot - Bar Chart
axs[0, 1].bar(['A', 'B', 'C', 'D'], y_bar, color=['red', 'blue', 'green', 'purple'])
axs[0, 1].set_title('Bar Chart')

# Third subplot - Scatter Plot
axs[1, 0].scatter(x_scatter, y_scatter, color='orange')
axs[1, 0].set_title('Scatter Plot')

# Fourth subplot - Pie Chart
axs[1, 1].pie(sizes_pie, labels=labels_pie, autopct='%1.1f%%', colors=['red', 'blue', 'green', 'purple'])
axs[1, 1].set_title('Pie Chart')

# Display the plots
plt.tight_layout()
plt.show()
